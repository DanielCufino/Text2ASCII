# %%
import numpy as np
import pandas as pd
import os
import PIL, PIL.Image
import base64
import io, math, json

import matplotlib as mpl
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None  # default='warn'

# %%
dataset = pd.read_csv("full_emoji_parsed.csv")

# %%
dataset[30:].head(30)
# Out:
#     Unnamed: 0   # emoji                        unicode  \
# 30          30  31     🤫                        U+1F92B
# 31          31  32     🤔                        U+1F914
# 32          32  33     🤐                        U+1F910
# 33          33  34     🤨                        U+1F928
# 34          34  35     😐                        U+1F610
# 35          35  36     😑                        U+1F611
# 36          36  37     😶                        U+1F636
# 37          37  38  😶‍🌫️  U+1F636 U+200D U+1F32B U+FE0F
# 38          38  39     😏                        U+1F60F
# 39          39  40     😒                        U+1F612
# 40          40  41     🙄                        U+1F644
# 41          41  42     😬                        U+1F62C
# 42          42  43   😮‍💨         U+1F62E U+200D U+1F4A8
# 43          43  44     🤥                        U+1F925
# 44          44  45     😌                        U+1F60C
# 45          45  46     😔                        U+1F614
# ...

# %%
# types = list(dataset.columns[11 +5:11 +16])
# types
types = ['Apple_ASCII']

# %%
SUBSET =

# %%
raw_data = []

for row in range(dataset.shape[0]):
    entry = dataset.iloc[row]
    for t in types:
        company = t.split("_")[0]
        description = entry['name']
        if isinstance(entry[t], str):

            json_entry = {
                "prompt": f'Please generate ASCII art of an emoji of {description}',
                "text": entry[t]
            }
            raw_data.append(json_entry)

# %%
raw_data_string = json.dumps(raw_data)
raw_data_file = open("raw_data_apple.json", "w")
raw_data_file.write(raw_data_string)
raw_data_file.close()

# %%
with open('raw_data.json', 'r') as file:
    test = json.load(file)
    print(test[0])

p = test[0]['prompt']

t = test[0]['text']
print(f'<BOS> {p} \n\n <RES>: \n\n {t} \n\n <EOS>')
# Out:
# {'prompt': 'Please generate ASCII art of an emoji of grinning face', 'text': '                                                           \n                     %?????******?????%                    \n                S???*****++;;;;;;++*****???S               \n             S???**++;::............::;;+**???%            \n           ???**+;::.....................:;+**???          \n         ???**+::::::::..............::::::::;**???        \n       %??**+;:::::::::::::::::::::::::::::::::;**??S      \n      ???*+;::::::::::::::::::::::::::::::::::;:;+*???     \n     ??**+;;;;;;;;;;;::::::::::::::::::;;;;;;;;;;;+*???    \n    %??*+;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;+*??%   \n   S??**+++++;;;;;;*%SS%+;;;;;;;;;;*%SS%+;;;;;;++++++*???  \n   ???*++++++++++;*#SSS#%+;;;;;;;;*##SS#S++++++++++++*??%  \n  *%??**++++++++++*#SSSS%++++++++;*SSSSSS+++++++++++**??%? \n  ????***++++++++++*%%%%+++++++++++*%%%%*++++++++++***??%% \n  %%??****+++++++++++++++++++++++++++++++++++++++++***??%% \n  %%?
# ...

# %%
